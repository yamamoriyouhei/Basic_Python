# %% [markdown]
# # 【確認課題】Matplotlib

# %%
# 使うライブラリ
# !pip install japanize-matplotlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import japanize_matplotlib
japanize_matplotlib.japanize()

# %% [markdown]
# ## 1問目
# 使うcsvはhist_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問1](./imgs/matplotlib/plot_1.png)

# %%
df_hist = pd.read_csv('./data/hist_data.csv')
plt.hist(df_hist['aデータ'],bins=30,label='aデータ',alpha=0.4,color='orange')
plt.hist(df_hist['bデータ'],bins=30,label='bデータ',alpha=0.4,color='lightgreen')
plt.legend()

# %% [markdown]
# ## 2問目
# 使うcsvはscatter_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問2](./imgs/matplotlib/plot_2.png)

# %%
df_scatter = pd.read_csv('./data/scatter_data.csv')
class_0 = df_scatter[df_scatter['class'] == 0]
class_1 = df_scatter[df_scatter['class'] == 1]
class_2 = df_scatter[df_scatter['class'] == 2]


plt.scatter(class_0['length (cm)'], class_0['width (cm)'], label='Class 0', c='red')
plt.scatter(class_1['length (cm)'], class_1['width (cm)'], label='Class 1', c='blue')
plt.scatter(class_2['length (cm)'], class_2['width (cm)'], label='Class 2', c='green')

plt.xlabel('Length (cm)')
plt.ylabel('Width (cm)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 3問目
# 使うcsvはline_data.csvです。下に2つの画像を表示するコードを書いてください。

# %% [markdown]
# ![問3_1](./imgs/matplotlib/plot_3_1.png)

# %% [markdown]
# ![問3_2](./imgs/matplotlib/plot_3_2.png)

# %%
df_line = pd.read_csv('./data/line_data.csv')

plt.plot(df_line['期間'], df_line['件数'],marker='o')
plt.xlabel('期間')
plt.ylabel('件数')
plt.title('期間ごとの件数の推移')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()


plt.bar(df_line['期間'],df_line['費用'])
plt.xlabel('期間')
plt.ylabel('費用')
plt.title('期間ごとの費用の推移"')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
